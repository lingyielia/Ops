# %% [markdown]
# ## Shapefiles used in the examples are extracted from the original shapefiles of:
# - [Law Enforcement Reporting Districts](https://egis3.lacounty.gov/dataportal/2010/10/05/law-enforcement-reporting-districts/)
# - [LAcounty_COMMUNITIES](https://egis3.lacounty.gov/dataportal/2010/10/21/citycommunity-boundaries/)
# - [Registrar Recorder Precincts](https://egis3.lacounty.gov/dataportal/2012/12/20/2012-precincts-as-of-march-9th/)

# %%
# %matplotlib inline
from __future__ import print_function, division
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
#Function for overlay
def spatial_overlays(df1, df2, how='intersection', reproject=True):
    """Perform spatial overlay between two polygons.

    Currently only supports data GeoDataFrames with polygons.
    Implements several methods that are all effectively subsets of
    the union.

    Parameters
    ----------
    df1 : GeoDataFrame with MultiPolygon or Polygon geometry column
    df2 : GeoDataFrame with MultiPolygon or Polygon geometry column
    how : string
        Method of spatial overlay: 'intersection', 'union',
        'identity', 'symmetric_difference' or 'difference'.
    use_sindex : boolean, default True
        Use the spatial index to speed up operation if available.

    Returns
    -------
    df : GeoDataFrame
        GeoDataFrame with new set of polygons and attributes
        resulting from the overlay

    """
    from functools import reduce
    df1 = df1.copy()
    df2 = df2.copy()
    df1['geometry'] = df1.geometry.buffer(0)
    df2['geometry'] = df2.geometry.buffer(0)
    if df1.crs!=df2.crs and reproject:
        print('Data has different projections.')
        print('Converted data to projection of first GeoPandas DatFrame')
        df2.to_crs(crs=df1.crs, inplace=True)
    if how=='intersection':
        # Spatial Index to create intersections
        spatial_index = df2.sindex
        df1['bbox'] = df1.geometry.apply(lambda x: x.bounds)
        df1['sidx']=df1.bbox.apply(lambda x:list(spatial_index.intersection(x)))
        pairs = df1['sidx'].to_dict()
        nei = []
        for i,j in pairs.items():
            for k in j:
                nei.append([i,k])
        pairs = gpd.GeoDataFrame(nei, columns=['idx1','idx2'], crs=df1.crs)
        pairs = pairs.merge(df1, left_on='idx1', right_index=True)
        pairs = pairs.merge(df2, left_on='idx2', right_index=True, suffixes=['_1','_2'])
        pairs['Intersection'] = pairs.apply(lambda x: (x['geometry_1'].intersection(x['geometry_2'])).buffer(0), axis=1)
        pairs = gpd.GeoDataFrame(pairs, columns=pairs.columns, crs=df1.crs)
        cols = pairs.columns.tolist()
        cols.remove('geometry_1')
        cols.remove('geometry_2')
        cols.remove('sidx')
        cols.remove('bbox')
        cols.remove('Intersection')
        dfinter = pairs[cols+['Intersection']].copy()
        dfinter.rename(columns={'Intersection':'geometry'}, inplace=True)
        dfinter = gpd.GeoDataFrame(dfinter, columns=dfinter.columns, crs=pairs.crs)
        dfinter = dfinter.loc[dfinter.geometry.is_empty==False]
        dfinter.drop(['idx1','idx2'], inplace=True, axis=1)
        return dfinter
    elif how=='difference':
        spatial_index = df2.sindex
        df1['bbox'] = df1.geometry.apply(lambda x: x.bounds)
        df1['sidx']=df1.bbox.apply(lambda x:list(spatial_index.intersection(x)))
        df1['new_g'] = df1.apply(lambda x: reduce(lambda x, y: x.difference(y).buffer(0), 
                                 [x.geometry]+list(df2.iloc[x.sidx].geometry)) , axis=1)
        df1.geometry = df1.new_g
        df1 = df1.loc[df1.geometry.is_empty==False].copy()
        df1.drop(['bbox', 'sidx', 'new_g'], axis=1, inplace=True)
        return df1
    elif how=='symmetric_difference':
        df1['idx1'] = df1.index.tolist()
        df2['idx2'] = df2.index.tolist()
        df1['idx2'] = np.nan
        df2['idx1'] = np.nan
        dfsym = df1.merge(df2, on=['idx1','idx2'], how='outer', suffixes=['_1','_2'])
        dfsym['geometry'] = dfsym.geometry_1
        dfsym.loc[dfsym.geometry_2.isnull()==False, 'geometry'] = dfsym.loc[dfsym.geometry_2.isnull()==False, 'geometry_2']
        dfsym.drop(['geometry_1', 'geometry_2'], axis=1, inplace=True)
        dfsym = gpd.GeoDataFrame(dfsym, columns=dfsym.columns, crs=df1.crs)
        spatial_index = dfsym.sindex
        dfsym['bbox'] = dfsym.geometry.apply(lambda x: x.bounds)
        dfsym['sidx'] = dfsym.bbox.apply(lambda x:list(spatial_index.intersection(x)))
        dfsym['idx'] = dfsym.index.values
        dfsym.apply(lambda x: x.sidx.remove(x.idx), axis=1)
        dfsym['new_g'] = dfsym.apply(lambda x: reduce(lambda x, y: x.difference(y).buffer(0), 
                         [x.geometry]+list(dfsym.iloc[x.sidx].geometry)) , axis=1)
        dfsym.geometry = dfsym.new_g
        dfsym = dfsym.loc[dfsym.geometry.is_empty==False].copy()
        dfsym.drop(['bbox', 'sidx', 'idx', 'idx1','idx2', 'new_g'], axis=1, inplace=True)
        return dfsym
    elif how=='union':
        dfinter = spatial_overlays(df1, df2, how='intersection')
        dfsym = spatial_overlays(df1, df2, how='symmetric_difference')
        dfunion = dfinter.append(dfsym)
        dfunion.reset_index(inplace=True, drop=True)
        return dfunion
    elif how=='identity':
        dfunion = spatial_overlays(df1, df2, how='union')
        cols1 = df1.columns.tolist()
        cols2 = df2.columns.tolist()
        cols1.remove('geometry')
        cols2.remove('geometry')
        cols2 = set(cols2).intersection(set(cols1))
        cols1 = list(set(cols1).difference(set(cols2)))
        cols2 = [col+'_1' for col in cols2]
        dfunion = dfunion[(dfunion[cols1+cols2].isnull()==False).values]
        return dfunion

# %% [markdown]
# ## Example 1

# %% [markdown]
# #### 1. Two shapefiles for overlay

# %%
coun_test1 = gpd.read_file('data/county_demo/county_demo.shp')
print (coun_test1)
coun_test1.plot(edgecolor='k');
# Out:
#   coun_comm_                                           geometry
# 0   Hi Vista  POLYGON ((-117.6672529361081 34.77575138627761...

# %%
law_test1 = gpd.read_file('data/law_demo/law_demo.shp')
print (law_test1)
law_test1.plot(edgecolor='k', alpha=0.5);
# Out:
#   repo_dist_                          repo_dis_1  \
# 0       1172  Carl O Gerhardy Wildlife Sanctuary
# 1       1197                   Lancaster Sheriff
#
#                                             geometry
# 0  (POLYGON ((-117.684784003094 34.6369653233286,...
# 1  POLYGON ((-117.6669411237361 34.64602684574505...

# %% [markdown]
# #### 2. Compare overlay results (spatial_overlay vs. arcgis)

# %% [markdown]
# #### 2.1 Number of polygons are different

# %%
#overlay result of spatial_ovelay
intersect_gpd1 = spatial_overlays(coun_test1, law_test1)
intersect_gpd1
# Out:
#   coun_comm_ repo_dist_                          repo_dis_1  \
# 0   Hi Vista       1197                   Lancaster Sheriff
# 1   Hi Vista       1172  Carl O Gerhardy Wildlife Sanctuary
#
#                                             geometry
# 0  POLYGON ((-117.666941843729 34.64546638501637,...
# 1  (POLYGON ((-117.684784003094 34.6369653233286,...

# %%
#overlay result of arcgis
intersect_arc1 = gpd.read_file('data/overlay1_arcgis/overlay1_arcgis.shp')
intersect_arc1
# Out:
#    FID_county coun_comm_  FID_law_de repo_dist_  \
# 0           0   Hi Vista           1       1197
# 1           0   Hi Vista           0       1172
# 2           0   Hi Vista           1       1197
#
#                            repo_dis_1  \
# 0                   Lancaster Sheriff
# 1  Carl O Gerhardy Wildlife Sanctuary
# 2                   Lancaster Sheriff
#
#                                             geometry
# 0  (POLYGON ((-117.7508658480909 34.6462390351968...
# 1  (POLYGON ((-117.6981190326431 34.6423131665127...
# 2  (POLYGON ((-117.6981190326431 34.6423131665127...

# %% [markdown]
# #### 2.2 Overall looks the same

# %%
#overlay result of spatial_ovelay
intersect_gpd1.plot(edgecolor='k')

# %%
#overlay result of arcgis
intersect_arc1.plot(edgecolor='k')

# %% [markdown]
# #### 2.3 Polygon Components

# %%
#overlay result of spatial_ovelay
for i in range(len(intersect_gpd1)):
    intersect_gpd1[intersect_gpd1.index==i].plot()

# %%
#overlay result of arcgis
for i in range(len(intersect_arc1)):
    intersect_arc1[intersect_arc1.index==i].plot()

# %% [markdown]
# ## Example 2

# %% [markdown]
# #### 1. Two shapefiles for overlay

# %%
law_test2 = gpd.read_file('data/law_test2/law_test2.shp')
print (coun_test1)
law_test2.plot(edgecolor='k');
# Out:
#   coun_comm_                                           geometry
# 0   Hi Vista  POLYGON ((-117.6672529361081 34.77575138627761...

# %%
prec_test2 = gpd.read_file('data/prec_test2/prec_test2.shp')
print (prec_test2)
prec_test2.plot(edgecolor='k', alpha=0.5);
# Out:
#   precinct_n  congress_d  senate_dis  assembly_d  community_ communit_1  \
# 0   1040052D        25.0        21.0        38.0       104.0    CASTAIC
# 1   1040052G        25.0        21.0        38.0       104.0    CASTAIC
# 2   1040071Y        25.0        21.0        38.0       104.0    CASTAIC
#
#    area_num             area_name precinct_1  \
# 0     836.0  SANTA CLARITA VALLEY    CASTAIC
# 1     836.0  SANTA CLARITA VALLEY    CASTAIC
# 2     836.0  SANTA CLARITA VALLEY    CASTAIC
#
#                                             geometry
# 0  POLYGON ((-118.660541548544 34.60312372128115,...
# 1  POLYGON ((-118.660541548544 34.60312372128115,...
# 2  POLYGON ((-118.5895976280062 34.51797997301639...

# %% [markdown]
# #### 2. Compare overlay results (spatial_overlay vs. arcgis)

# %% [markdown]
# #### 2.1 Number of polygons are different

# %%
#overlay result of spatial_ovelay
intersect_gpd2 = spatial_overlays(law_test2, prec_test2)
intersect_gpd2
# Out:
#   repo_dist_                          repo_dis_1 precinct_n  congress_d  \
# 0       8307  Castaic Lake State Recreation Area   1040052D        25.0
# 3       8307        Santa Clarita Valley Sheriff   1040052D        25.0
# 1       8307  Castaic Lake State Recreation Area   1040052G        25.0
# 4       8307        Santa Clarita Valley Sheriff   1040052G        25.0
# 2       8307  Castaic Lake State Recreation Area   1040071Y        25.0
# 5       8307        Santa Clarita Valley Sheriff   1040071Y        25.0
#
#    senate_dis  assembly_d  community_ communit_1  area_num  \
# 0        21.0        38.0       104.0    CASTAIC     836.0
# 3        21.0        38.0       104.0    CASTAIC     836.0
# 1        21.0        38.0       104.0    CASTAIC     836.0
# 4        21.0        38.0       104.0    CASTAIC     836.0
# 2        21.0        38.0       104.0    CASTAIC     836.0
# 5        21.0        38.0       104.0    CASTAIC     836.0
#
#               area_name precinct_1  \
# 0  SANTA CLARITA VALLEY    CASTAIC
# 3  SANTA CLARITA VALLEY    CASTAIC
# 1  SANTA CLARITA VALLEY    CASTAIC
# 4  SANTA CLARITA VALLEY    CASTAIC
# 2  SANTA CLARITA VALLEY    CASTAIC
# 5  SANTA CLARITA VALLEY    CASTAIC
#
#                                             geometry
# 0  POLYGON ((-118.6638656610757 34.60956524063867...
# 3  POLYGON ((-118.6721240401232 34.60312466630052...
# 1  (POLYGON ((-118.66061673023 34.60312373017047,...
# 4  (POLYGON ((-118.6605486348086 34.6019067627361...
# 2  (POLYGON ((-118.633309380227 34.55924263726257...
# 5  (POLYGON ((-118.6333093795918 34.5592426372634...

# %%
#overlay result of arcgis
intersect_arc2 = gpd.read_file('data/overlay2_arcgis/overlay2_arcgis.shp')
intersect_arc2
# Out:
#     OBJECTID  FID_prec_t precinct_n  congress_d  senate_dis  assembly_d  \
# 0          1           0   1040052D        25.0        21.0        38.0
# 1          2           0   1040052D        25.0        21.0        38.0
# 2          3           1   1040052G        25.0        21.0        38.0
# 3          4           1   1040052G        25.0        21.0        38.0
# 4          5           2   1040071Y        25.0        21.0        38.0
# 5          6           2   1040071Y        25.0        21.0        38.0
# 6          7           0   1040052D        25.0        21.0        38.0
# 7          8           0   1040052D        25.0        21.0        38.0
# 8          9           1   1040052G        25.0        21.0        38.0
# 9         10           1   1040052G        25.0        21.0        38.0
# 10        11           2   1040071Y        25.0        21.0        38.0
# 11        12           2   1040071Y        25.0        21.0        38.0
#
#     community_ communit_1  area_num             area_name precinct_1  \
# 0        104.0    CASTAIC     836.0  SANTA CLARITA VALLEY    CASTAIC
# 1        104.0    CASTAIC     836.0  SANTA CLARITA VALLEY    CASTAIC
# 2        104.0    CASTAIC     836.0  SANTA CLARITA VALLEY    CASTAIC
# 3        104.0    CASTAIC     836.0  SANTA CLARITA VALLEY    CASTAIC
# 4        104.0    CASTAIC     836.0  SANTA CLARITA VALLEY    CASTAIC
# 5        104.0    CASTAIC     836.0  SANTA CLARITA VALLEY    CASTAIC
# 6        104.0    CASTAIC     836.0  SANTA CLARITA VALLEY    CASTAIC
# 7        104.0    CASTAIC     836.0  SANTA CLARITA VALLEY    CASTAIC
# 8        104.0    CASTAIC     836.0  SANTA CLARITA VALLEY    CASTAIC
# 9        104.0    CASTAIC     836.0  SANTA CLARITA VALLEY    CASTAIC
# 10       104.0    CASTAIC     836.0  SANTA CLARITA VALLEY    CASTAIC
# 11       104.0    CASTAIC     836.0  SANTA CLARITA VALLEY    CASTAIC
#
#     FID_Law_te repo_dist_                          repo_dis_1  Shape_Leng  \
# 0            0       8307  Castaic Lake State Recreation Area    0.018946
# 1            1       8307        Santa Clarita Valley Sheriff    0.034106
# 2            0       8307  Castaic Lake State Recreation Area    0.145691
# 3            1       8307        Santa Clarita Valley Sheriff    0.140511
# 4            0       8307  Castaic Lake State Recreation Area    0.312421
# 5            1       8307        Santa Clarita Valley Sheriff    0.091898
# 6            0       8307  Castaic Lake State Recreation Area    0.029117
# 7            1       8307        Santa Clarita Valley Sheriff    0.029117
# 8            0       8307  Castaic Lake State Recreation Area    0.306878
# 9            1       8307        Santa Clarita Valley Sheriff    0.306878
# 10           0       8307  Castaic Lake State Recreation Area    0.681970
# 11           1       8307        Santa Clarita Valley Sheriff    0.681970
#
#       Shape_Area                                           geometry
# 0   7.847620e-06  (POLYGON ((-118.6638739691084 34.6065040815981...
# 1   1.777001e-05  (POLYGON ((-118.6652965697808 34.6095785363204...
# 2   1.908879e-05  (POLYGON ((-118.6606167307775 34.6031237296764...
# 3   1.822813e-05  (POLYGON ((-118.6692178459268 34.6031245183818...
# 4   8.383026e-05  (POLYGON ((-118.6204689873538 34.5126838550759...
# 5   8.367778e-07  (POLYGON ((-118.6080528860318 34.5591171032717...
# 6   2.875281e-05  POLYGON ((-118.6652965697808 34.60957853632044...
# 7   2.875281e-05  POLYGON ((-118.6652965697808 34.60957853632044...
# 8   7.645351e-04  (POLYGON ((-118.6621827265516 34.6031239275272...
# 9   7.645351e-04  (POLYGON ((-118.6621827265516 34.6031239275272...
# 10  1.683694e-03  (POLYGON ((-118.6080641140676 34.5591171887073...
# 11  1.683694e-03  (POLYGON ((-118.6080641140676 34.5591171887073...

# %% [markdown]
# #### 2.2 Overall looks different in the upper left corner

# %%
#overlay result of spatial_ovelay
intersect_gpd2.plot(edgecolor='k')

# %%
#overlay result of arcgis
intersect_arc2.plot(edgecolor='k')

# %% [markdown]
# #### 2.3 Polygon Components

# %%
#overlay result of spatial_ovelay
for i in range(len(intersect_gpd2)):
    intersect_gpd2[intersect_gpd2.index==i].plot()

# %%
#overlay result of arcgis
for i in range(len(intersect_arc2)):
    intersect_arc2[intersect_arc2.index==i].plot()
